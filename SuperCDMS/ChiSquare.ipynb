# %%
#we may need some code in the ../python directory and/or matplotlib styles
import sys
sys.path.append('../python/')

#matplotlib for plotting
import matplotlib as mpl
from matplotlib import pyplot as plt
import lmfit as lm

plt.style.use('mplstyles/stylelib/standard.mplstyle')

#other computational libraries
import numpy as np

# %%
# import data from text file
import pandas as pds



ge_data = pds.read_csv("SuperCDMS/PhysRevD.99.062001-data/MarchAprilFinal.txt", skiprows=1, \
                         names=['time', 'blah'], \
                         delim_whitespace=False
                     )

ge_data = ge_data.sort_values(by='time')

print (ge_data.head(10))

t = np.asarray(ge_data["time"], dtype=np.float32)

print (t)
# Out:
#         time    blah
# 9   506.1574  5.2894
# 5   507.4013  5.9058
# 8   509.4632  5.6750
# 10  509.8995  5.2232
# 13  510.0812  5.0349
# 3   512.5145  6.3243
# 19  512.7067  4.2205
# 12  513.7324  5.0628
# 14  513.8779  4.9122
# 4   514.5219  6.1499
# [ 506.1574  507.4013  509.4632  509.8995  510.0812  512.5145  512.7067
#   513.7324  513.8779  514.5219  516.8201  517.7107  518.5185  519.2819
#   519.8351  524.4211  525.2859  525.2859  526.9375  528.7008  529.4175
#   530.1161  534.9125  535.2761  536.9121  537.7742  543.2328  550.717
#   551.226   553.132   553.3139  553.7683  554.0956  557.6922  558.5466
#   565.1764  566.9474  567.3552  571.5335  574.8757  576.3014  578.0828
#   578.1919  580.6901  583.0324  584.7126  587.0472  593.4147  593.986
#   594.7132  596.1207  602.9245  616.2568  616.7476  623.1592  623.5592
#   627.683   627.9011  637.3381  637.8289  638.3016  638.3275  648.4008
#   651.4703  651.517   652.3974  652.5064  660.6087  661.3799  661.4708
# ...

# %%
#plt.hist(t, bins=72)
#plt.show
#count = sum(t<=550 & t>=500) #help
#print(count)
error = (0,0)

#print(np.shape(error))
#if count == 0:
 #   error = (0.00, 1.29)
    
#if count == 1:
 #   error = (0.37, 2.75)

#if count == 2:
 #   error = (0.74, 4.25)

#if count == 3:
 #   error = (1.10, 5.30)

#if count == 4:
 #   error = (2.34, 6.78)
    
#if count == 5:
 #   error = (2.75, 7.81)
    
#if count == 6:
 #   error = (3.82, 9.28)
    
#if count == 7:
 #   error = (4.25, 10.30)
    
#if count == 8:
 #   error = (5.30, 11.32)
    
#if count == 9:
 #   error = (6.33, 12.79)
    
#if count == 12:
 #   error = (9.28, 17.30)
    
#weight = 1/(error[1]-error[0])
    
    
#matplotlib.pyplot.errorbar(t, yerr=error)
#fitbins=72
fitbins=72
min_t = np.min(t)
print(min_t)
max_t = np.max(t-min_t)
t = t-min_t
counts, bins = np.histogram(t[t<=max_t],bins=fitbins)
thing = (bins[:-1]+bins[1:])/2
fig,axes = plt.subplots(1,1, figsize=(9,8))
error1 = [0.00,0.37,0.74,1.10,2.34,2.75,3.82,4.25,5.30,6.33,6.78,7.81,8.83,9.28]
error2 = [1.29,2.75,4.25,5.30,6.78,7.81,9.28,10.30,11.32,12.79,13.81,14.82,16.29,17.30]
ntot = counts
ntot_plus = np.zeros(np.shape(ntot))
ntot_minus = np.zeros(np.shape(ntot))
for i,ncount in enumerate(ntot):
    if ncount<=13:
        ntot_plus[i] = error2[ncount]-ncount
        ntot_minus[i] = ncount-error1[ncount]
    else:
        ntot_plus[i] = np.sqrt(ncount)
        ntot_minus[i] = np.sqrt(ncount)
ax1=axes
ax1.errorbar(thing, counts, yerr=[ntot_minus,ntot_plus], marker='o', markersize=8, linestyle = 'none')
plt.show(fig)
print(max_t)
print(min_t)
# Out:
# 506.1574
# 925.4482
# 506.1574

# %%
weight = (1/((ntot_plus+ntot_minus)/2))
print(weight)
# Out:
# [0.24937656 0.30959752 0.39525692 0.36630037 0.39525692 0.33057851
#  0.36630037 0.84033613 0.56980057 0.45045045 0.45045045 0.39525692
#  0.39525692 0.39525692 0.36630037 0.56980057 0.47619048 0.47619048
#  1.5503876  0.47619048 0.47619048 0.39525692 0.39525692 0.45045045
#  0.47619048 0.45045045 0.56980057 0.47619048 0.84033613 0.47619048
#  0.45045045 1.5503876  0.47619048 0.84033613 0.47619048 0.45045045
#  0.56980057 0.47619048 0.84033613 0.56980057 0.56980057 0.84033613
#  0.56980057 0.56980057 0.84033613 0.56980057 0.84033613 0.84033613
#  0.47619048 0.56980057 0.84033613 1.5503876  1.5503876  0.84033613
#  0.84033613 0.84033613 0.84033613 0.84033613 0.84033613 0.56980057
#  0.84033613 0.56980057 1.5503876  0.84033613 1.5503876  0.56980057
#  0.84033613 0.84033613 0.84033613 0.84033613 0.84033613 0.56980057]

# %%
def function(t, tstop, alpha, b):
    return (((1/(1+b))*np.exp(-t/alpha)/(alpha*(1-np.exp(-tstop/alpha))))+(b/tstop))
           
#print(function(1,2,3,4))
fig,axes = plt.subplots(1,1, figsize=(9,8))

ax1=axes
timespace=bins[1]-bins[0]
counts1 = counts/np.sum(counts)/timespace
weight1 = weight*np.sum(counts)*timespace
#remove bins 7,8,18
idx = np.zeros(np.shape(counts1))
c2 = np.zeros(np.shape(counts1))
for i,c in enumerate(counts1):
    c2[i] =c
    idx[i] = i
cGoodBins = (idx!=7)&(idx!=8)&(idx!=18)
c2 = c2[cGoodBins]
thing2 = thing[cGoodBins]
weight2=weight[cGoodBins]
print(np.shape(c2))
print(np.shape(thing2))
ax1.errorbar(thing2, c2, yerr=[ntot_minus[cGoodBins]/np.sum(counts)/timespace,ntot_plus[cGoodBins]/np.sum(counts)/timespace], marker='o', markersize=8, linestyle = 'none')
#ax1.errorbar(thing2, c2, color='r',marker='o', markersize=8, linestyle = 'none')

#print(function(0,1450,271.2,1)*4000)
x = np.linspace(0,max_t,num=100)
print (function(x,max_t,271.2,1))

ax1.plot(x,function(x,max_t,400.2,0))
plt.show(fig)
# Out:
# (69,)
# (69,)
# [0.00298706 0.00292246 0.00286005 0.00279976 0.00274151 0.00268524
#  0.00263087 0.00257834 0.00252759 0.00247857 0.0024312  0.00238544
#  0.00234123 0.00229851 0.00225725 0.00221738 0.00217886 0.00214165
#  0.0021057  0.00207096 0.00203741 0.00200499 0.00197367 0.00194341
#  0.00191417 0.00188593 0.00185864 0.00183228 0.00180681 0.0017822
#  0.00175843 0.00173546 0.00171327 0.00169183 0.00167112 0.00165111
#  0.00163178 0.00161311 0.00159506 0.00157763 0.00156079 0.00154452
#  0.0015288  0.00151361 0.00149894 0.00148476 0.00147107 0.00145784
#  0.00144505 0.0014327  0.00142077 0.00140925 0.00139811 0.00138735
#  0.00137696 0.00136691 0.00135721 0.00134784 0.00133878 0.00133003
#  0.00132158 0.00131341 0.00130552 0.0012979  0.00129054 0.00128342
#  0.00127655 0.00126991 0.00126349 0.0012573  0.00125131 0.00124552
#  0.00123993 0.00123453 0.00122932 0.00122428 0.00121941 0.0012147
#  0.00121016 0.00120577 0.00120152 0.00119743 0.00119347 0.00118964
# ...

# %%
#test the integral...
import pandas as pd
def integrate_df(df):
    # (left-sided rectangular integral)
    dE = -df['E'].diff(periods = -1)
    dE.iat[-1] = dE.iat[-2]
    A = df['spec']*dE
    return A.sum()

pdf = pd.DataFrame()
ttot = np.linspace(0,max_t,num=10000)
trange = (ttot>=0)
pdf['E']=ttot[trange]
pdf['spec']=function(ttot[trange],max_t,40.2,0)
print(integrate_df(pdf))
# Out:
# 1.0011516117997235

# %%
f_mod = lm.Model(function)
f_params = f_mod.make_params()               # define parameters

f_params.add('alpha',     vary=True,  value=395.7601, min=0,max=8000)  # half life

# amplitude
f_params.add('b', vary=True,  value=0.1,      min=0.0,max=100)  
# time
f_params.add('tstop',  vary=False,  value=1450)

#do the fitting
counts1 = counts/np.sum(counts)/timespace
weight1 = weight*np.sum(counts)*timespace
weight2 = weight2*np.sum(counts)*timespace

#f_fit = f_mod.fit(counts1, f_params, t = thing, weights = weight1)
f_fit = f_mod.fit(c2, f_params, t = thing2, weights = weight2)

f_fit
# Out:
# <h2> Model</h2> Model(function) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>38</td><td></td></tr><tr><td># data points</td><td>69</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 33.2949516</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.49693958</td><td></td></tr><tr><td>Akaike info crit.</td><td>-46.2803498</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-41.8121368</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> tstop </td><td>  1450.00000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 1450 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> alpha </td><td>  219.075506 </td><td>  38.8373850 </td><td> (17.73%) </td><td> 395.7601 </td><td>  0.00000000 </t
# ...

# %%
fig,axes = plt.subplots(1,1, figsize=(9,8))

ax1=axes
#ax1.errorbar(thing, counts1, yerr=[ntot_minus/np.sum(counts)/timespace,ntot_plus/np.sum(counts)/timespace], marker='o', markersize=8, linestyle = 'none')
ax1.errorbar(thing2, c2, yerr=[ntot_minus[cGoodBins]/np.sum(counts)/timespace,ntot_plus[cGoodBins]/np.sum(counts)/timespace], marker='o', markersize=8, linestyle = 'none')

#print(function(0,1450,271.2,1)*4000)
x = np.linspace(500,1450,num=100)
print (function(x,1450,271.2,0))

#ax1.plot(x,function(x,1450,419.277958,38.9762712))
#ax1.plot(thing,f_fit.best_fit)
ax1.plot(thing2,f_fit.best_fit)
plt.show(fig)
# Out:
# [5.86264971e-04 5.65883668e-04 5.46210915e-04 5.27222078e-04
#  5.08893382e-04 4.91201876e-04 4.74125410e-04 4.57642601e-04
#  4.41732812e-04 4.26376121e-04 4.11553300e-04 3.97245789e-04
#  3.83435674e-04 3.70105663e-04 3.57239066e-04 3.44819771e-04
#  3.32832229e-04 3.21261430e-04 3.10092885e-04 2.99312612e-04
#  2.88907110e-04 2.78863353e-04 2.69168763e-04 2.59811203e-04
#  2.50778954e-04 2.42060709e-04 2.33645551e-04 2.25522943e-04
#  2.17682714e-04 2.10115049e-04 2.02810471e-04 1.95759834e-04
#  1.88954309e-04 1.82385377e-04 1.76044811e-04 1.69924673e-04
#  1.64017300e-04 1.58315294e-04 1.52811517e-04 1.47499076e-04
#  1.42371321e-04 1.37421831e-04 1.32644407e-04 1.28033070e-04
#  1.23582043e-04 1.19285756e-04 1.15138827e-04 1.11136065e-04
#  1.07272457e-04 1.03543167e-04 9.99435237e-05 9.64690211e-05
#  9.31153084e-05 8.98781863e-05 8.67536017e-05 8.37376422e-05
#  8.08265316e-05 7.80166247e-05 7.53044032e-05 7.26864712e-05
# ...
